# %% [markdown]
# # OpenCV Tutorial

# %%
# import opencv module
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread('picture3.jpg')

# %%
img
# Out:
# array([[[ 74,  77,  82],
#         [ 75,  78,  83],
#         [ 76,  78,  86],
#         ...,
#         [116, 140, 160],
#         [116, 140, 160],
#         [115, 139, 159]],
#
#        [[ 73,  76,  81],
#         [ 74,  77,  82],
#         [ 74,  76,  84],
#         ...,
#         [115, 139, 159],
#         [116, 140, 160],
#         [115, 139, 159]],
#
#        [[ 76,  79,  84],
#         [ 76,  79,  84],
#         [ 75,  77,  85],
#         ...,
#         [115, 139, 159],
#         [115, 139, 159],
#         [115, 139, 159]],
#
#        ...,
#        [[139, 127, 109],
#         [139, 127, 109],
#         [139, 127, 109],
#         ...,
#         [143, 119,  97],
#         [139, 114,  94],
#         [142, 117,  97]],
#
#        [[139, 127, 109],
#         [139, 127, 109],
#         [139, 127, 109],
#         ...,
#         [143, 120,  98],
#         [138, 115,  93],
#         [140, 117,  95]],
#
#        [[139, 127, 109],
#         [139, 127, 109],
#         [139, 127, 109],
#         ...,
#         [143, 120,  98],
#         [138, 115,  93],
#         [139, 116,  94]]], dtype=uint8)

# %%
# display the image
#cv2.imshow('image',img)   #only this line will cause an error
# for single images, matplotlib may be better
plt.imshow(img)
plt.show()

# %% [markdown]
# Notice anything weird? OpenCV uses BGR color scheme, while images are usually in RGB. Thus, we must convert the image to BGR first

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(img)
plt.show()

# %% [markdown]
# Now we get the correct image. Lets run some operations on the image

# %% [markdown]
# ## Hough Transform

# %%
edges = cv2.Canny(img, 100, 200, apertureSize = 3)
edges2 = cv2.Canny(img, 0, 100, apertureSize = 3)
edges3 = cv2.Canny(img, 0, 600)
plt.imshow(edges); plt.show()
plt.imshow(edges2); plt.show()
plt.imshow(edges3); plt.show()

# %% [markdown]
# Change parameters?

# %%
# turn on webcam, set parameters
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 200)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 400)

# %%
while True:
    _,frame = cap.read()
    edges = cv2.Canny(frame,100,200,apertureSize = 3)
    cv2.imshow('original', frame)
    #cv2.imshow('canny',edges)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
